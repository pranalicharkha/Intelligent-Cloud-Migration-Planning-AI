# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading faker-40.39.0-py3-none-any.whl.metadata (16 kB)
# Downloading faker-40.39.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.2 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.39.0

# %%
from faker import Faker
import pandas as pd
import random

fake = Faker()

# %%
num_apps = 150

applications = []

for i in range(num_apps):

    app = {
        "application_id": f"APP{i+1:03d}",
        "application_name": fake.bs(),
        "cpu_usage": round(random.uniform(0.1, 1.0), 2),
        "memory_usage": round(random.uniform(0.1, 1.0), 2),
        "age_years": random.randint(1, 15),
        "criticality": random.choice(["Low", "Medium", "High"]),
        "compliance_flag": random.choice([0, 1])
    }

    applications.append(app)

df = pd.DataFrame(applications)

df.head()
# Out:
#   application_id                          application_name  cpu_usage  \
# 0         APP001           extend wireless infrastructures       0.57
# 1         APP002             grow innovative architectures       0.91
# 2         APP003              evolve seamless action-items       0.76
# 3         APP004         strategize cross-platform vortals       0.16
# 4         APP005  e-enable bricks-and-clicks methodologies       0.79
#
#    memory_usage  age_years criticality  compliance_flag
# 0          0.95          9        High                1
# 1          0.50          3         Low                1
# 2          0.46          3         Low                1
# 3          0.81          1        High                1
# 4          0.39          7         Low                0

# %%
app_ids = df["application_id"].tolist()

dependency_ids = []

for app_id in app_ids:

    possible_dependencies = [
        x for x in app_ids
        if x != app_id
    ]

    num_dependencies = random.randint(0, 5)

    dependencies = random.sample(
        possible_dependencies,
        min(num_dependencies, len(possible_dependencies))
    )

    dependency_ids.append(",".join(dependencies))

df["dependency_ids"] = dependency_ids

df["dependency_count"] = df["dependency_ids"].apply(
    lambda x: 0 if x == "" else len(x.split(","))
)

# %%
df.to_csv(
    "application_portfolio.csv",
    index=False
)

# %%
df.shape
# Out:
# (150, 9)
